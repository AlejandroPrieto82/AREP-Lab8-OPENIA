# %% [markdown]
# # Guía 3 — Introducción a LangChain con OpenAI API
# Curso: **IA en el Aula — Nivel Avanzado**
# Profesor: **Luis Daniel Benavides Navarro**
# Fecha: **Octubre 2025**
#
# En esta guía aprenderás los conceptos básicos de **LangChain**, una librería diseñada para construir aplicaciones impulsadas por modelos de lenguaje, integrando la API de OpenAI con flujos más complejos. Exploraremos cómo crear un primer **prompt chain**, administrar memoria y usar herramientas para componer respuestas inteligentes.

# %% [markdown]
# ## 1️⃣ Instalación y configuración inicial
# LangChain se instala como cualquier otra librería de Python. También usaremos `python-dotenv` para gestionar la clave de OpenAI. Ejecute la siguiente celda:

# %%
# %pip install openai langchain python-dotenv langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (2.6.1)
# Collecting langchain
#   Downloading langchain-1.0.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: python-dotenv in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (1.2.1)
# Collecting langchain-openai
#   Downloading langchain_openai-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from openai) (4.15.0)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain)
#   Downloading langchain_core-1.0.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting langgraph<1.1.0,>=1.0.0 (from langchain)
#   Downloading langgraph-1.0.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading langsmith-0.4.38-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (25.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_checkpoint-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_prebuilt-1.0.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2025.10.23-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting requests>=2.26.0 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: colorama in c:\users\samuel.prieto-r\appdata\roaming\python\python311\site-packages (from tqdm>4->openai) (0.4.6)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading ormsgpack-1.11.0-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading orjson-3.11.4-cp311-cp311-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Downloading langchain-1.0.2-py3-none-any.whl (107 kB)
# Downloading langchain_openai-1.0.1-py3-none-any.whl (81 kB)
# Downloading langchain_core-1.0.1-py3-none-any.whl (467 kB)
# Downloading langgraph-1.0.1-py3-none-any.whl (155 kB)
# Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#    ---------------------------------------- 879.4/879.4 kB 7.9 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph_checkpoint-3.0.0-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.1-py3-none-any.whl (28 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading langsmith-0.4.38-py3-none-any.whl (397 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
# Downloading regex-2025.10.23-cp311-cp311-win_amd64.whl (277 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl (31 kB)
# Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.4-cp311-cp311-win_amd64.whl (131 kB)
# Downloading ormsgpack-1.11.0-cp311-cp311-win_amd64.whl (112 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, urllib3, tenacity, regex, pyyaml, ormsgpack, orjson, jsonpointer, charset_normalizer, requests, jsonpatch, tiktoken, requests-toolbelt, langgraph-sdk, langsmith, langchain-core, langgraph-checkpoint, langchain-openai, langgraph-prebuilt, langgraph, langchain
# Successfully installed charset_normalizer-3.4.4 jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.0.2 langchain-core-1.0.1 langchain-openai-1.0.1 langgraph-1.0.1 langgraph-checkpoint-3.0.0 langgraph-prebuilt-1.0.1 langgraph-sdk-0.2.9 langsmith-0.4.38 orjson-3.11.4 ormsgpack-1.11.0 pyyaml-6.0.3 regex-2025.10.23 requests-2.32.5 requests-toolbelt-1.0.0 tenacity-9.1.2 tiktoken-0.12.0 urllib3-2.5.0 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2️⃣ Cargar variables de entorno y cliente OpenAI
# Crea un archivo `.env` con tu clave de API y cárgala para poder usarla dentro de LangChain. Esto evita exponer tu clave en el código fuente.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()  # Cargar archivo .env
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError("No se encontró la clave OPENAI_API_KEY en el archivo .env")

# Crear cliente LangChain con OpenAI
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
print("Cliente LangChain con OpenAI inicializado correctamente.")
# Out:
# Cliente LangChain con OpenAI inicializado correctamente.

# %% [markdown]
# ## 3️⃣ Primer ejemplo: Prompt simple con LangChain
# LangChain utiliza **chains** (cadenas de pasos) para procesar información. Comencemos con una cadena simple que envía un mensaje al modelo y obtiene la respuesta.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Initialize the LLM (uses your OpenAI API key from environment)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=1)

# Create a simple prompt
prompt = ChatPromptTemplate.from_template(
    "Explica en dos frases el concepto de {tema}."
)

# Combine the components using LCEL (LangChain Expression Language)
chain = prompt | llm | StrOutputParser()

# Run it
result = chain.invoke({"tema": "aprendizaje automático"})
print(result)
# Out:
# El aprendizaje automático es una rama de la inteligencia artificial que permite a las computadoras aprender y hacer predicciones o decisiones basadas en datos sin ser programadas explícitamente para cada tarea. Utiliza algoritmos que identifican patrones en grandes volúmenes de información, mejorando su rendimiento a medida que se les proporciona más datos.

# %% [markdown]
# ### Explicación
# - **ChatPromptTemplate:** define la estructura del mensaje que se envía al modelo.
# - **ChatOpenAI:** la conexión real al modelo.
# - **chain** crea la cadena de componentes usando LCEL (LangChain Expression Language).
# - **StrOutputParser** convierte la salida estructurada del modelo en texto plano.
# - **chain.invoke:** ejecuta la cadena pasando los valores del prompt.
#
# Este patrón permite reutilizar prompts para distintos temas o contextos.

# %% [markdown]
# ## 4️⃣ Ejemplo 2: Encadenar múltiples pasos
# LangChain permite combinar varios pasos en una misma ejecución. En este ejemplo, crearemos dos prompts: uno para definir un tema y otro para generar una aplicación educativa basada en el resultado.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from operator import itemgetter

# 1) LLM (usa tu OPENAI_API_KEY en el entorno)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
to_str = StrOutputParser()

# 2) Paso 1: explicar brevemente el concepto de {tema}
primer_prompt = ChatPromptTemplate.from_template(
    "Explica brevemente el concepto de {tema}."
)
primer_paso = primer_prompt | llm | to_str
# `primer_paso` produce un string, por ejemplo: "La realidad aumentada es ..."

# 3) Paso 2: proponer una aplicación educativa usando la salida del paso 1 como {concepto}
segundo_prompt = ChatPromptTemplate.from_template(
    "Propón una aplicación educativa del siguiente concepto: {concepto}."
)
segundo_paso = segundo_prompt | llm | to_str

# 4) Encadenar: mapear la entrada {tema} al primer paso, y su salida a {concepto} del segundo
cadena_secuencial = {"concepto": primer_paso} | segundo_paso

# 5) Ejecutar la cadena completa
resultado = cadena_secuencial.invoke({"tema": "realidad aumentada"})
print(resultado)
# Out:
# **Aplicación Educativa: "ExplorAR" - Exploración Aumentada del Mundo Natural**
#
# **Descripción de la Aplicación:**
# "ExplorAR" es una aplicación educativa que utiliza la realidad aumentada para enseñar a los estudiantes sobre la biología, la geografía y la ecología del entorno natural que les rodea. A través de sus dispositivos móviles, los usuarios pueden explorar su entorno local, interactuar con elementos de la naturaleza y aprender sobre ellos de una manera divertida e inmersiva.
#
# **Características Principales:**
#
# 1. **Exploración del Entorno:**
#    - Los estudiantes pueden utilizar la cámara de su dispositivo para escanear su entorno (parques, jardines, bosques, etc.). La aplicación identificará plantas, árboles, insectos y animales en tiempo real.
#
# 2. **Información Interactiva:**
#    - Al apuntar su dispositivo hacia un objeto natural, los usuarios recibirán información instantánea sobre ese elemento, como su nombre científico, hábitat, características, funciones ecológicas y datos curiosos. Esto se presentará en forma de tarjetas informativas que aparecerán superpuestas en la pantalla.
#
# 3. **Juegos de Aprendizaje:**
#    - La aplicación incluirá juegos interactivos, como cuestionarios y desafíos, que permitirán a los estudiantes poner a prueba sus conocimientos sobre la flora y fauna que han aprendido. Por ejemplo, un juego de "caza de especies" donde deben encontrar y registrar diferentes tipos de plantas o animales.
#
# 4. **Proyectos Colaborativos:**
#    - Los estudiantes podrán trabajar en proyectos grupales, donde tendrán que investigar y presentar un ecosistema local. La aplicación facilitará la recopilación de datos y la creación de presentaciones interactivas utilizando la información obtenida a través de la RA.
#
# 5. **Realidad Aumentada en el Aula:**
#    - En el aula, los profesores pueden utilizar la aplicación para realizar lecciones interactivas. Por ejemplo, al estudiar un ecosistema específico, los estudiantes pueden "ver" cómo interactúan diferentes especies en un hábitat simulado.
#
# 6. **Recorridos Virtuales:**
#    - La aplicación ofrecerá recorridos virtuales por diferentes ecosistemas de todo el mundo, permitiendo a los estudiantes aprender sobre la biodiversidad global y la importancia de la conservación.
#
# 7. **Integración con Currículo Escolar:**
#    - Los contenidos de la aplicación estarán alineados con los estándares educativos nacionales, permitiendo a los profesores integrar "ExplorAR" en sus lecciones de ciencias naturales y estudios sociales.
#
# **Beneficios:**
# - Fomenta el aprendizaje activo y la curiosidad por el entorno natural.
# - Mejora la retención de información a través de experiencias interactivas.
# - Promueve el trabajo en equipo y el aprendizaje colaborativo.
# - Contribuye a la educación ambiental y la conciencia sobre la conservación.
#
# "ExplorAR" no solo enriquecerá la experiencia educativa de los estudiantes, sino que también los motivará a explorar y apreciar el mundo natural que los rodea.

# %% [markdown]
# ### Explicación
# - **cadena_secuencial:** permite conectar varias cadenas; la salida de una se convierte en la entrada de la siguiente.
# - En este caso, el modelo primero explica el tema y luego sugiere una aplicación educativa.
#
# Este tipo de flujo es ideal para generar contenido didáctico o ideas para proyectos en clase.

# %% [markdown]
# ## 5️⃣ Ejemplo 3: Añadir memoria a la conversación
# LangChain incluye módulos de **memoria** para mantener contexto entre múltiples interacciones. Esto permite simular conversaciones educativas más naturales, donde el modelo recuerda temas previos.

# %%
# Instalar si hace falta:
# %pip install -U langchain langchain-openai

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.output_parsers import StrOutputParser

# LLM (requiere OPENAI_API_KEY en el entorno)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
to_str = StrOutputParser()

# Prompt con hueco para el historial
prompt = ChatPromptTemplate.from_messages([
    ("system", "Eres un asistente educativo claro y conciso."),
    MessagesPlaceholder("chat_history"),      # ← aquí va la memoria
    ("human", "{input}")
])

# Cadena base
chain = prompt | llm | to_str

# Memoria simple como lista de mensajes
history: list = []

def chat(user_text: str) -> str:
    """
    Envía un turno del usuario, usa el historial y actualiza la memoria
    con el par (usuario, asistente).
    """
    global history
    # Ejecutar la cadena inyectando el historial actual
    answer = chain.invoke({"input": user_text, "chat_history": history})
    # Actualizar memoria (guardar los dos mensajes)
    history += [HumanMessage(content=user_text), AIMessage(content=answer)]
    return answer

# --- Ejemplo de uso (tres turnos) ---
print(chat("Hola, soy un profesor de informática."))
print(chat("¿Puedes explicarme cómo introducir IA a mis estudiantes?"))
print(chat("¿Qué ejemplos prácticos puedo usar en la clase?"))
# Out:
# ¡Hola! ¿En qué puedo ayudarte hoy en tu labor como profesor de informática?
# ¡Claro! Aquí tienes algunos pasos y enfoques para introducir la inteligencia artificial (IA) a tus estudiantes:
#
# 1. **Conceptos Básicos**:
#    - Comienza explicando qué es la IA: sistemas que pueden realizar tareas que normalmente requieren inteligencia humana, como reconocimiento de voz, toma de decisiones y aprendizaje.
#    - Presenta términos clave como aprendizaje automático (machine learning), redes neuronales, y procesamiento del lenguaje natural.
#
# 2. **Aplicaciones Prácticas**:
#    - Muestra ejemplos de IA en la vida cotidiana: asistentes virtuales (Siri, Alexa), recomendaciones de productos (Amazon, Netflix), y chatbots.
#    - Discute aplicaciones en diferentes campos: medicina, finanzas, transporte, y entretenimiento.
#
# 3. **Proyectos Prácticos**:
#    - Propón proyectos sencillos, como crear un chatbot básico utilizando plataformas como Chatbot.com o herramientas de programación como Python con bibliotecas como NLTK o TensorFlow.
#    - Utiliza herramientas de IA accesibles como Google Teachable Machine para que los estudiantes experimenten con el entrenamiento de modelos de IA.
#
# 4. **Ética y Responsabilidad**:
#    - Introduce discusiones sobre la ética en IA: sesgos en algoritmos, privacidad de datos y el impacto social de la automatización.
#    - Fomenta el pensamiento crítico sobre cómo la IA puede afectar la vida de las personas.
#
# 5. **Recursos y Herramientas**:
#    - Proporciona acceso a recursos en línea, como cursos gratuitos de plataformas como Coursera, edX o Khan Academy.
#    - Recomienda libros y artículos que aborden la IA de manera accesible.
#
# 6. **Fomentar la Curiosidad**:
#    - Anima a los estudiantes a investigar sobre avances recientes en IA y a presentar sus hallazgos.
#    - Organiza debates o foros sobre el futuro de la IA y su potencial.
#
# Recuerda adaptar el contenido al nivel de conocimiento y edad de tus estudiantes. ¡Buena suerte!
# Aquí tienes algunos ejemplos prácticos de IA que puedes utilizar en clase:
#
# 1. **Chatbots**:
#    - Crea un chatbot simple utilizando plataformas como Chatbot.com o Dialogflow. Los estudiantes pueden diseñar un bot que responda a preguntas sobre un tema específico.
#
# 2. **Reconocimiento de Imágenes**:
#    - Utiliza Google Teachable Machine para que los estudiantes entrenen un modelo que reconozca diferentes objetos o sonidos. Pueden crear un proyecto donde la IA identifique imágenes que ellos mismos tomen.
#
# 3. **Análisis de Sentimientos**:
#    - Introduce bibliotecas de Python como NLTK o TextBlob para que los estudiantes analicen sentimientos en textos. Pueden usar reseñas de películas o comentarios en redes sociales para practicar.
#
# 4. **Predicciones Sencillas**:
#    - Usa un conjunto de datos simple (como el de Iris) y enseña a los estudiantes a construir un modelo de predicción utilizando Python y Scikit-learn. Pueden predecir la especie de una flor basada en sus características.
#
# 5. **Juegos con IA**:
#    - Implementa juegos sencillos donde los estudiantes programen un agente que aprenda a jugar (por ejemplo, un juego de Tic-Tac-Toe). Pueden usar algoritmos básicos para que el agente mejore su rendimiento.
#
# 6. **Arte Generativo**:
#    - Explora herramientas como DeepArt o RunwayML, donde los estudiantes pueden crear arte utilizando algoritmos de IA. Esto puede combinarse con discusiones sobre creatividad y tecnología.
#
# 7. **Detección de Fraude**:
#    - Presenta un caso de estudio sobre cómo las empresas utilizan IA para detectar fraudes en transacciones financieras. Puedes simular un escenario donde los estudiantes identifiquen patrones sospechosos.
#
# 8. **Asistentes Virtuales**:
#    - Analiza cómo funcionan los asistentes virtuales (como Siri o Google Assistant). Los estudiantes pueden diseñar un asistente simple que responda a comandos básicos.
#
# 9. **Proyectos de Datos Abiertos**:
#    - Utiliza conjuntos de datos abiertos (como Kaggle) para que los estudiantes realicen análisis de datos y apliquen modelos de IA. Pueden trabajar en grupos para resolver un problema real.
#
# Estos ejemplos no solo ayudarán a los estudiantes a entender la IA, sino que también fomentarán su creatividad y habilidades de resolución de problemas. ¡Diviértete enseñando!

# %% [markdown]
# ### Explicación
# - **ConversationBufferMemory:** almacena los mensajes anteriores en la conversación.
# - **ConversationChain:** combina el modelo con la memoria.
# - Esta funcionalidad es útil para tutores inteligentes o chatbots educativos que requieren continuidad en el diálogo.

# %% [markdown]
# ## 6️⃣ Buenas prácticas con LangChain + OpenAI
# - Usa prompts **claros y estructurados**: el modelo responde mejor cuando la tarea está bien definida.
# - Controla `temperature` según la tarea: bajo (0.1–0.3) para precisión, alto (0.7–0.9) para creatividad.
# - Guarda logs o historiales si tu aplicación incluye interacción prolongada.
# - Limita la longitud de las respuestas con `max_tokens` para evitar costos o respuestas excesivas.
# - Documenta tus cadenas (`LLMChain`) para reusarlas en distintos contextos educativos.

# %% [markdown]
# ## ✅ Conclusión
# Has aprendido los fundamentos de LangChain: prompts, chains, memoria y flujo secuencial. Estos conceptos son la base para desarrollar asistentes educativos, tutores personalizados o sistemas de generación de contenido en el aula. En la próxima guía implementaremos un **asistente educativo con RAG (Retrieval-Augmented Generation)** usando tus propios materiales docentes.
